# %%
import pandas as pd
import numpy as np

df = pd.read_excel(r"F:\COMPRAS\BASE DE DADOS - MODELOS v3.xlsx", sheet_name="CONTROLE DE COMPRA", header=1)
df
# Out:
#                          FORNECEDOR CENTRALIZ. LOJA CENTR. DIA PED. SMJ  \
# 0            @MONTANHA CARNE DE SOL        NaN         NaN          NaN
# 1    0800 FLEX SERVICOS DE TELECOMU        NaN         NaN          NaN
# 2    A S PRODUTOS PAIS E FILHOS LTD        NaN         NaN      SEGUNDA
# 3            ABS DISTRIBUIDORA LTDA    3 LOJAS         SMJ       QUINTA
# 4                           ABSOLUT        NaN         NaN          NaN
# ..                              ...        ...         ...          ...
# 662                   WR EMBALAGENS        NaN         NaN          NaN
# 663   AYMORES EMBALAGENS EIRELI EPP        NaN         NaN          NaN
# 664                          ARTMAQ        NaN         NaN          NaN
# 665  COTERMICO BRASILEIRA IND DE PR        NaN         NaN          NaN
# 666                           LIANE    4 LOJAS         SMJ      SEGUNDA
#
#      FREQ. SMJ  PRAZO PD SMJ  DIA PED. VIX  FREQ. VIX  PRAZO PD VIX  \
# ...

# %%
# Supondo que o DataFrame após a alteração de tipo seja chamado df_tipo_alterado
colunas_selecionadas = ["FORNECEDOR", "COMPRADOR", "STATUS DO FORNECEDOR"]

# Selecionando as colunas especificadas
df_selecionado = df[colunas_selecionadas]
df_selecionado = df_selecionado[df_selecionado["STATUS DO FORNECEDOR"] == "ATIVO"]

df_selecionado
# Out:
#                          FORNECEDOR COMPRADOR STATUS DO FORNECEDOR
# 2    A S PRODUTOS PAIS E FILHOS LTD   GUSTAVO                ATIVO
# 3            ABS DISTRIBUIDORA LTDA   JAIDSON                ATIVO
# 6                ADM DO BRASIL LTDA   JAIDSON                ATIVO
# 9                              AKIO   GUSTAVO                ATIVO
# 14                 ALIMENTOS WILSON   GUSTAVO                ATIVO
# ..                              ...       ...                  ...
# 662                   WR EMBALAGENS   GUSTAVO                ATIVO
# 663   AYMORES EMBALAGENS EIRELI EPP   GUSTAVO                ATIVO
# 664                          ARTMAQ   GUSTAVO                ATIVO
# 665  COTERMICO BRASILEIRA IND DE PR   GUSTAVO                ATIVO
# 666                           LIANE   GUSTAVO                ATIVO
#
# [359 rows x 3 columns]
